# %%
using GLMakie

# %%
ts = 0.0:0.05:6
# Out:
# 0.0:0.05:6.0

# %% [markdown]
# ## Dense version of [20 20 20]

# %%
evolEE0s = Float64[]
evolEE4s = Float64[]
evolEE6s = Float64[]
evolEE8s = Float64[]
evolEE10s = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text0.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE0s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text4.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE4s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text6.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE6s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text8.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE8s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text10.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE10s, ln)
    end
end

# %%
fig = Figure()
lines(fig[1,1], ts, evolEE0s,linewidth=1.5)
lines!(fig[1,1], ts, evolEE4s, linewidth=1.5)
lines!(fig[1,1], ts, evolEE6s, linewidth=1.5)
lines!(fig[1,1], ts, evolEE8s, linewidth=1.5)
lines!(fig[1,1], ts, evolEE10s, linewidth=1.5, color=:black)
fig
# Out:
# Figure()

# %% [markdown]
# ## Dense version of [0 0 60]

# %%
evolEE0s_new = Float64[]
evolEE4s_new = Float64[]
evolEE6s_new = Float64[]
evolEE8s_new = Float64[]
evolEE10s_new = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text0.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE0s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text4.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE4s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text6.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE6s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text8.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE8s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text10.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE10s_new, ln)
    end
end

# %%
fig2 = Figure()
lines(fig2[1,1], ts, evolEE0s_new,linewidth=1.5)
lines!(fig2[1,1], ts, evolEE4s_new, linewidth=1.5)
lines!(fig2[1,1], ts, evolEE6s_new, linewidth=1.5)
lines!(fig2[1,1], ts, evolEE8s_new, linewidth=1.5)
lines!(fig2[1,1], ts, evolEE10s_new, linewidth=1.5, color=:black)
fig2
# Out:
# Figure()

# %% [markdown]
# ## Dense version of [10 40 10]

# %%
evolEE0s_newnew = Float64[]
evolEE4s_newnew = Float64[]
evolEE6s_newnew = Float64[]
evolEE8s_newnew = Float64[]
evolEE10s_newnew = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text0.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE0s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text4.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE4s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text6.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE6s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text8.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE8s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text10.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE10s_newnew, ln)
    end
end

# %%
fig3 = Figure()
lines(fig3[1,1], ts, evolEE0s_newnew,linewidth=1.5)
lines!(fig3[1,1], ts, evolEE4s_newnew, linewidth=1.5)
lines!(fig3[1,1], ts, evolEE6s_newnew, linewidth=1.5)
lines!(fig3[1,1], ts, evolEE8s_newnew, linewidth=1.5)
lines!(fig3[1,1], ts, evolEE10s_newnew, linewidth=1.5, color=:black)
fig3
# Out:
# Figure()

# %% [markdown]
# ## The case of [20 20 20]

# %%
evolEE0s = Float64[]
evolEE4s = Float64[]
evolEE6s = Float64[]
evolEE8s = Float64[]
evolEE10s = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee/text0.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE0s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee/text4.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE4s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee/text6.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE6s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee/text8.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE8s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee/text10.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE10s, ln)
    end
end

# %%
fig = Figure()
lines(fig[1,1], ts, evolEE0s,linewidth=1.5)
lines!(fig[1,1], ts, evolEE4s, linewidth=1.5)
lines!(fig[1,1], ts, evolEE6s, linewidth=1.5)
lines!(fig[1,1], ts, evolEE8s, linewidth=1.5)
lines!(fig[1,1], ts, evolEE10s, linewidth=1.5, color=:black)
fig
# Out:
# Figure()

# %% [markdown]
# ## The case of [0 0 60]

# %%
evolEE0s_new = Float64[]
evolEE4s_new = Float64[]
evolEE6s_new = Float64[]
evolEE8s_new = Float64[]
evolEE10s_new = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_new/text0.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE0s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_new/text4.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE4s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_new/text6.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE6s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_new/text8.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE8s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_new/text10.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE10s_new, ln)
    end
end

# %%
fig2 = Figure()
ax2 = fig2[1, 1] = Axis(fig2)
scatterlines!(ts, evolEE0s_new, linewidth=1, label=L"\gamma=0")
scatterlines!(ts, evolEE4s_new, linewidth=1, marker=:rect, label=L"\gamma=4")
scatterlines!(ts, evolEE6s_new, linewidth=1, marker=:utriangle, label=L"\gamma=6")
scatterlines!(ts, evolEE8s_new, linewidth=1, marker=:diamond, label=L"\gamma=8")
scatterlines!(ts, evolEE10s_new,color=:red, linewidth=1, marker=:star5, label=L"\gamma=10")
axislegend(ax2)
#fig2[1, 2] = Legend(fig2, ax2, "Trig Functions", framevisible = false)
fig2
# Out:
# Figure()

# %% [markdown]
# ## The case of [10 40 10]

# %%
evolEE0s_newnew = Float64[]
evolEE4s_newnew = Float64[]
evolEE6s_newnew = Float64[]
evolEE8s_newnew = Float64[]
evolEE10s_newnew = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_newnew/text0.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE0s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_newnew/text4.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE4s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_newnew/text6.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE6s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_newnew/text8.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE8s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/ees/ee_newnew/text10.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE10s_newnew, ln)
    end
end

# %%
fig3 = Figure()
scatterlines(fig3[1,1], ts, evolEE0s_newnew, linewidth=1)
scatterlines!(fig3[1,1], ts, evolEE4s_newnew, linewidth=1, marker=:rect)
scatterlines!(fig3[1,1], ts, evolEE6s_newnew, linewidth=1, marker=:utriangle)
scatterlines!(fig3[1,1], ts, evolEE8s_newnew, linewidth=1, marker=:diamond)
scatterlines!(fig3[1,1], ts, evolEE10s_newnew,color=:red, linewidth=1, marker=:star5)
fig3
# Out:
# Figure()
