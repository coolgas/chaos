# %%
using GLMakie

# %%
ts = 0.0:0.05:20
ts1 = 0.0:0.2:5
gammas_new = 0.0:1:8
# Out:
# 0.0:1.0:8.0

# %% [markdown]
# ## Dense version of [20 20 20]

# %%
evolEE0s = Float64[]
evolEE4s = Float64[]
evolEE6s = Float64[]
evolEE8s = Float64[]
evolEE10s = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text0.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE0s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text4.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE4s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text6.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE6s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text8.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE8s, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee/text10.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE10s, ln)
    end
end

# %% [markdown]
# ## Dense version of [0 0 60]

# %%
evolEE0s_new = Float64[]
evolEE4s_new = Float64[]
evolEE6s_new = Float64[]
evolEE8s_new = Float64[]
evolEE10s_new = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text0.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE0s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text4.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE4s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text6.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE6s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text8.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE8s_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_new/text10.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE10s_new, ln)
    end
end

# %% [markdown]
# ## Dense version of [10 40 10]

# %%
evolEE0s_newnew = Float64[]
evolEE4s_newnew = Float64[]
evolEE6s_newnew = Float64[]
evolEE8s_newnew = Float64[]
evolEE10s_newnew = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text0.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE0s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text4.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE4s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text6.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE6s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text8.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE8s_newnew, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/dense/ees/ee_newnew/text10.txt", "r") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(evolEE10s_newnew, ln)
    end
end

# %% [markdown]
# ## Read the average values of ee and std

# %%
ave = Float64[]
ave_new = Float64[]
ave_newnew = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/aves/avee/aveEEs.txt") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(ave, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/aves/avee_new/aveEEs_new.txt") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(ave_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/aves/avee_newnew/aveEEs_newnew.txt") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(ave_newnew, ln)
    end
end

std = Float64[]
std_new = Float64[]
std_newnew = Float64[]

io = open("/Users/tianyiyan/Desktop/Chaos/data/aves/log_stdee/text0.txt") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(std, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/aves/log_stdee_new/text0.txt") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(std_new, ln)
    end
end

io = open("/Users/tianyiyan/Desktop/Chaos/data/aves/log_stdee_newnew/text0.txt") do io
    for ln in eachline(io)
        ln = parse(Float64, ln)
        append!(std_newnew, ln)
    end
end

# %%
fontsize_theme = Theme(fontsize = 45)
set_theme!(fontsize_theme)

f = Figure(resolution=(1500,1500))
ax1 = Axis(f[1,1], ylabel=L"S_{EE}")
lines!(ax1, ts, evolEE0s, color=:black, linestyle=:dash, linewidth=5.0, label=L"$\gamma=0$")
lines!(ax1, ts, evolEE4s, color=:blue, linewidth=3.5, label=L"$\gamma=4")
#lines!(ax1, ts, evolEE6s, label=L"$\gamma=6$")
lines!(ax1, ts, evolEE8s, color=:red, linewidth=3.5, label=L"$\gamma=8")
#lines!(ax1, ts, evolEE10s, color="red", label=L"$\gamma=10$")
hidexdecorations!(ax1,grid=false)
Label(f[1, 1], "(a)", tellwidth=false, tellheight=false,valign = :top, halign = :left, padding = (10, 5, 5, 1))
axislegend(ax1, position=:rb)

ax2 = Axis(f[2,1], ylabel=L"S_{EE}")
lines!(ax2, ts, color=:black, linewidth=3.5, evolEE0s_new)
lines!(ax2, ts, color=:blue, linewidth=3.5, evolEE4s_new)
#lines!(ax2, ts, evolEE6s_new)
lines!(ax2, ts, linewidth=3.5, color=:red, evolEE8s_new)
#lines!(ax2, ts, evolEE10s_new, color="red")
hidexdecorations!(ax2,grid=false)
Label(f[2, 1], "(b)", tellwidth=false, tellheight=false,valign = :top, halign = :left, padding = (10, 5, 5, 1))

ax3 = Axis(f[3,1], xlabel=L"$tJ$", ylabel=L"S_{EE}")
lines!(ax3, ts, color=:black, linewidth=3.5, evolEE0s_newnew)
lines!(ax3, ts, color=:blue, linewidth=3.5, evolEE4s_newnew)
#lines!(ax3, ts, evolEE6s_newnew)
lines!(ax3, ts, color=:red, linewidth=3.5, evolEE8s_newnew)
#lines!(ax3, ts, evolEE10s_newnew, color="red")
Label(f[3, 1], "(c)", tellwidth=false, tellheight=false,valign = :top, halign = :left, padding = (10, 5, 5, 1))

ax4 = Axis(f[1,2], ylabel=L"\log(\bar{S}_{EE})")
scatter!(ax4, gammas_new, log.(ave), color="black")
errorbars!(gammas_new, log.(ave), std, whiskerwidth=10)
hidexdecorations!(ax4,grid=false)
Label(f[1, 2], "(d)", tellwidth=false, tellheight=false,valign = :top, halign = :left, padding = (530, 5, 5, 1))

ax5 = Axis(f[2,2], ylabel=L"\log(\bar{S}_{EE})")
scatter!(ax5, gammas_new, log.(ave_new), color="black")
errorbars!(gammas_new, log.(ave_new), std_new, whiskerwidth=10)
hidexdecorations!(ax5,grid=false)
Label(f[2, 2], "(e)", tellwidth=false, tellheight=false,valign = :top, halign = :left, padding = (530, 5, 5, 1))

ax6 = Axis(f[3,2], xlabel=L"$\gamma/J$", ylabel=L"\log(\bar{S}_{EE})")
scatter!(ax6, gammas_new, log.(ave_newnew),  color="black")
errorbars!(gammas_new, log.(ave_newnew), std_newnew, whiskerwidth=10)
Label(f[3, 2], "(f)", tellwidth=false, tellheight=false,valign = :top, halign = :left, padding = (530, 5, 5, 1))

#f[1,1] = Legend(f, ax1, framevisible=false)

f
# Out:
# Figure()

# %%
save("/Users/tianyiyan/Desktop/Chaos/pics/pic1.png",f)
# Out:
# GLMakie.Screen(...)

# %% [markdown]
# ## Number evolutions

# %%
using Chaos
using LinearAlgebra
# Out:
# ┌ Info: Precompiling Chaos [0aea4425-8685-4cf8-ab93-d00eaca7e4b3]
# └ @ Base loading.jl:1423
# ┌ Warning: Package Chaos does not have LinearAlgebra in its dependencies:
# │ - If you have Chaos checked out for development and have
# │   added LinearAlgebra as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with Chaos
# └ Loading LinearAlgebra into Chaos from project dependency, future warnings for Chaos are suppressed.

# %%
Na = 60; # number of atoms
Ls = 3; # number of wells

Hbs = integer_partition(N=Na, L=Ls);
Lb = length(Hbs) # the dimension of the Hilbert space
# Out:
# 1891

# %%
HLs = zeros(Float64, Lb, Lb)
for i in 1:Ls-1
    HLs += hopping_pair(m=i, Na=Na, Hbs=Hbs)
end
Hhop = HLs + HLs';

Honsite = zeros(Float64, Lb, Lb);
for j in 1:Lb
    for k in 1:Lb
        if j == k
            sum = 0
            for l in 1:Ls
                sum += Hbs[j][l]^2 - Hbs[j][l]
            end
            Honsite[j,k] += sum
        end
    end
end

function Htit(γ::Float64)
    Htit = zeros(Float64, Lb, Lb)
    for j in 1:Lb
        for k in 1:Lb
            if j == k
                for l in 1:Ls
                    Htit[j,k] += -(l-(Ls+1)/2)*γ*Hbs[j][l]
                end
            end

        end
    end
    return Htit
end

Λ(delta::Int64, d::Float64, C6::Float64, R::Float64) = C6 / ((delta)^6*d^6 + R^6)

# Here 'd' is the lattice constant.
function Hsc(d::Float64, C6::Float64, R::Float64)
    Hsc = zeros(Float64, Lb, Lb)
    for j in 1:Lb
        for k in 1:Lb
            if j == k
                for l in 1:Ls
                    for m in 1:Ls
                        if l-m == 0
                            Hsc[j,k] += Λ(0,d,C6,R)*Hbs[j][l]*Hbs[j][m]
                        elseif abs(m-l) == 1
                            Hsc[j,k] += Λ(1,d,C6,R)*Hbs[j][l]*Hbs[j][m]
                        elseif abs(m-l) == 2
                            Hsc[j,k] += Λ(2,d,C6,R)*Hbs[j][l]*Hbs[j][m]
                        else
                            continue
                        end
                    end
                end
            end
        end
    end
    return Hsc
end

function Htot(;γ::Float64, J::Float64, g::Float64, d::Float64, C6::Float64, R::Float64)
    Htot = Htit(γ) - J*Hhop + (g/2)*Honsite + (1/2)*Hsc(d,C6,R)
    return Htot
end
# Out:
# Htot (generic function with 1 method)

# %%
J = 1.0
#g = -0.137
g = -0.05
d = 1.5
C6 = 100.0
R = 3.0
#gammas = -5.0:0.1:5.0
gammas = 0:0.2:10
eigs = zeros(Float64, Lb, length(gammas));

# %%
H0 = Htot(γ=0.0, J=J, g=g, d=d, C6=C6, R=R);
H1 = Htot(γ=1.0, J=J, g=g, d=d, C6=C6, R=R);
H15 = Htot(γ=1.5, J=J, g=g, d=d, C6=C6, R=R);
H2 = Htot(γ=2.0, J=J, g=g, d=d, C6=C6, R=R);
H3 = Htot(γ=3.0, J=J, g=g, d=d, C6=C6, R=R);
H4 = Htot(γ=4.0, J=J, g=g, d=d, C6=C6, R=R);
H6 = Htot(γ=6.0, J=J, g=g, d=d, C6=C6, R=R);
H7 = Htot(γ=7.0, J=J, g=g, d=d, C6=C6, R=R);
H8 = Htot(γ=8.0, J=J, g=g, d=d, C6=C6, R=R);
H9 = Htot(γ=9.0, J=J, g=g, d=d, C6=C6, R=R);
H10 = Htot(γ=10.0, J=J, g=g, d=d, C6=C6, R=R);

# %% [markdown]
# ## Quenching Dynamics

# %%
# I now only makes this function works given the initial state with equal
# number of atoms in each site. But I potentially can extend it to arbitrary initial state.
function evolEE(;H::Matrix{Float64},t::Float64,basis::Vector{Vector{Int64}},init::Vector{Int})
    
    if t == 0.0
        EE = 0.0
    else
        vec = state_evolution(H=H,t=t,basis=basis,init=init)
        #rdmat = reduced_density_matrix(Na=Na, state=vec, Hbs=Hbs)
        rdmat = reduced_density_matrix(state=vec, Na=Na, Ls=Ls, Rd=1)
        vals = svd(rdmat).S
        #EE = -transpose(conj(vals).*vals)*log.(conj(vals).*(vals))
        #vals_squd = vals.*conj(vals)
        EE = -transpose(vals)*log.(vals)
    end
    
    return EE
end
# Out:
# evolEE (generic function with 1 method)

# %%
function evolEE_random(;H::Matrix{Float64},t::Float64,basis::Vector{Vector{Int64}},init::Vector{Float64})
    
    if t == 0.0
        rdmat = reduced_density_matrix(state=init, Na=Na, Ls=Ls, Rd=1)
        vals = svd(rdmat).S
        EE = -transpose(vals)*log.(vals)
    else
        vec = state_evolution_random(H=H,t=t,basis=basis,init=init)
        #rdmat = reduced_density_matrix(Na=Na, state=vec, Hbs=Hbs)
        rdmat = reduced_density_matrix(state=vec, Na=Na, Ls=Ls, Rd=1)
        vals = svd(rdmat).S
        #EE = -transpose(conj(vals).*vals)*log.(conj(vals).*(vals))
        #vals_squd = vals.*conj(vals)
        EE = -transpose(vals)*log.(vals)
    end
    
    return EE
end
# Out:
# evolEE_random (generic function with 1 method)

# %%
# Here the quench will happen at time t1.
function quench(;H1::Matrix{Float64}, H2::Matrix{Float64},
        t0::Float64, t1::Float64, t2::Float64,
        basis::Vector{Vector{Int64}}, init::Vector{Int64},
        Na::Int64, Ls::Int64, Rd::Int64)
    
    @assert t0<=t1<=t2
    
    ts_init = t0:0.1:t1
    ts_quenched = t1:0.1:t2
    ts_quenched = ts_quenched[2:end]
    
    init_len = length(ts_init)
    quench_len = length(ts_quenched)
    
    # below we calculate the unquenched EEs
    EEs_unquenched = vec(zeros(Float64, 1, init_len))
    for i in 1:init_len
        init_vec = state_evolution(H=H1, t=ts_init[i], basis=Hbs, init=init)
        init_rdmat = reduced_density_matrix(state=init_vec, Na=Na, Ls=Ls, Rd=Rd)
        init_vals = svd(init_rdmat).S
        init_EE = -transpose(init_vals)*log.(init_vals)
        EEs_unquenched[i] = init_EE
    end
    
    # below we calculate the quenched EEs
    EEs_quenched = vec(zeros(Float64, 1, quench_len))
    init_vec = state_evolution(H=H1, t=t1, basis=Hbs, init=init)
    for i in 1:quench_len
        evol_vec = state_evolution_random(H=H2, t=ts_quenched[i], basis=Hbs, init=init_vec)
        evol_rdmat = reduced_density_matrix(state=evol_vec, Na=Na, Ls=Ls, Rd=1)
        evol_vals = svd(evol_rdmat).S
        evol_EE = -transpose(evol_vals)*log.(evol_vals)
        EEs_quenched[i] = evol_EE
    end
    
    return append!(EEs_unquenched, EEs_quenched)
end
# Out:
# quench (generic function with 1 method)

# %% [markdown]
# ## Population

# %%
ts2 = Float64[]
for i in 0.0:0.05:20
    push!(ts2,i)
end

# %%
evol_num1 = evolution_number(H=H4, init=vec([0 0 60]), basis=Hbs, site=1, ts=collect(ts2))
evol_num2 = evolution_number(H=H4, init=vec([0 0 60]), basis=Hbs, site=2, ts=collect(ts2))
evol_num3 = evolution_number(H=H4, init=vec([0 0 60]), basis=Hbs, site=3, ts=collect(ts2));

# %%
evol_num81 = evolution_number(H=H8, init=vec([0 0 60]), basis=Hbs, site=1, ts=collect(ts2))
evol_num82 = evolution_number(H=H8, init=vec([0 0 60]), basis=Hbs, site=2, ts=collect(ts2))
evol_num83 = evolution_number(H=H8, init=vec([0 0 60]), basis=Hbs, site=3, ts=collect(ts2));

# %%
evol_num01 = evolution_number(H=H0, init=vec([0 0 60]), basis=Hbs, site=1, ts=collect(ts2))
evol_num02 = evolution_number(H=H0, init=vec([0 0 60]), basis=Hbs, site=2, ts=collect(ts2))
evol_num03 = evolution_number(H=H0, init=vec([0 0 60]), basis=Hbs, site=3, ts=collect(ts2));

# %%
evol_num41_new = evolution_number(H=H4, init=vec([20 20 20]), basis=Hbs, site=1, ts=collect(ts2))
evol_num42_new = evolution_number(H=H4, init=vec([20 20 20]), basis=Hbs, site=2, ts=collect(ts2))
evol_num43_new = evolution_number(H=H4, init=vec([20 20 20]), basis=Hbs, site=3, ts=collect(ts2));

# %%
evol_num81_new = evolution_number(H=H8, init=vec([20 20 20]), basis=Hbs, site=1, ts=collect(ts2))
evol_num82_new = evolution_number(H=H8, init=vec([20 20 20]), basis=Hbs, site=2, ts=collect(ts2))
evol_num83_new = evolution_number(H=H8, init=vec([20 20 20]), basis=Hbs, site=3, ts=collect(ts2));

# %%
evol_num01_new = evolution_number(H=H0, init=vec([20 20 20]), basis=Hbs, site=1, ts=collect(ts2))
evol_num02_new = evolution_number(H=H0, init=vec([20 20 20]), basis=Hbs, site=2, ts=collect(ts2))
evol_num03_new = evolution_number(H=H0, init=vec([20 20 20]), basis=Hbs, site=3, ts=collect(ts2));

# %%
evol_num01_newnew = evolution_number(H=H0, init=vec([10 40 10]), basis=Hbs, site=1, ts=collect(ts2))
evol_num02_newnew = evolution_number(H=H0, init=vec([10 40 10]), basis=Hbs, site=2, ts=collect(ts2))
evol_num03_newnew = evolution_number(H=H0, init=vec([10 40 10]), basis=Hbs, site=3, ts=collect(ts2));

# %%
evol_num41_newnew = evolution_number(H=H4, init=vec([10 40 10]), basis=Hbs, site=1, ts=collect(ts2))
evol_num42_newnew = evolution_number(H=H4, init=vec([10 40 10]), basis=Hbs, site=2, ts=collect(ts2))
evol_num43_newnew = evolution_number(H=H4, init=vec([10 40 10]), basis=Hbs, site=3, ts=collect(ts2));

# %%
evol_num81_newnew = evolution_number(H=H8, init=vec([10 40 10]), basis=Hbs, site=1, ts=collect(ts2))
evol_num82_newnew = evolution_number(H=H8, init=vec([10 40 10]), basis=Hbs, site=2, ts=collect(ts2))
evol_num83_newnew = evolution_number(H=H8, init=vec([10 40 10]), basis=Hbs, site=3, ts=collect(ts2));

# %%
io = open("./data/num/104010/8/num1.txt", "w") do io
    for i in evol_num81_newnew
        println(io, i)
    end
end

io = open("./data/num/104010/8/num2.txt", "w") do io
    for i in evol_num82_newnew
        println(io, i)
    end
end

io = open("./data/num/104010/8/num3.txt", "w") do io
    for i in evol_num83_newnew
        println(io, i)
    end
end

# %%
# evol_num1_new = evolution_number(H=H15, init=vec([20 20 20]), basis=Hbs, site=1, ts=collect(ts2))
# evol_num2_new = evolution_number(H=H15, init=vec([20 20 20]), basis=Hbs, site=2, ts=collect(ts2))
# evol_num3_new = evolution_number(H=H15, init=vec([20 20 20]), basis=Hbs, site=3, ts=collect(ts2));

# %%
f2 = Figure(resolution=(500,500))
lines(f2[1,1], ts2, evol_num1)
lines!(f2[1,1], ts2, evol_num2)
lines!(f2[1,1], ts2, evol_num3)

f2
# Out:
# Figure()
