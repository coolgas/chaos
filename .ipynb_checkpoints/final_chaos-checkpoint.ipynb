# %%
using Combinatorics
using LinearAlgebra
using LaTeXStrings
using Chaos
using Statistics
using CSV
using DataFrames
using GLMakie
using SpecialFunctions
#using LsqFit
# Out:
# ┌ Info: Precompiling Chaos [0aea4425-8685-4cf8-ab93-d00eaca7e4b3]
# └ @ Base loading.jl:1423
# ┌ Warning: Package Chaos does not have LinearAlgebra in its dependencies:
# │ - If you have Chaos checked out for development and have
# │   added LinearAlgebra as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with Chaos
# └ Loading LinearAlgebra into Chaos from project dependency, future warnings for Chaos are suppressed.

# %%
Na = 60; # number of atoms
Ls = 3; # number of wells

# %% [markdown]
# ### The particle conserved basis

# %%
Hbs = integer_partition(N=Na, L=Ls);

# %%
Lb = length(Hbs) # the dimension of the Hilbert space
# Out:
# 1891

# %%
Lb_shouldbe = binomial(Na+Ls-1, Na)
# Out:
# 1891

# %% [markdown]
# ### The hopping Hamiltonian

# %%
HLs = zeros(Float64, Lb, Lb)
for i in 1:Ls-1
    HLs += hopping_pair(m=i, Na=Na, Hbs=Hbs)
end

# %%
Hhop = HLs + HLs';

# %% [markdown]
# ### The onsite interaction

# %%
Honsite = zeros(Float64, Lb, Lb);

# %%
for j in 1:Lb
    for k in 1:Lb
        if j == k
            sum = 0
            for l in 1:Ls
                sum += Hbs[j][l]^2 - Hbs[j][l]
            end
            Honsite[j,k] += sum
        end
    end
end

# %% [markdown]
# ### The tilt potential

# %%
function Htit(γ::Float64)
    Htit = zeros(Float64, Lb, Lb)
    for j in 1:Lb
        for k in 1:Lb
            if j == k
                for l in 1:Ls
                    Htit[j,k] += -(l-(Ls+1)/2)*γ*Hbs[j][l]
                end
            end

        end
    end
    return Htit
end
# Out:
# Htit (generic function with 1 method)

# %% [markdown]
# ### Soft-core interactions

# %%
Λ(delta::Int64, d::Float64, C6::Float64, R::Float64) = C6 / ((delta)^6*d^6 + R^6)
# Out:
# Λ (generic function with 1 method)

# %%
# Here 'd' is the lattice constant.
function Hsc(d::Float64, C6::Float64, R::Float64)
    Hsc = zeros(Float64, Lb, Lb)
    for j in 1:Lb
        for k in 1:Lb
            if j == k
                for l in 1:Ls
                    for m in 1:Ls
                        if l-m == 0
                            Hsc[j,k] += 2*Λ(0,d,C6,R)*Hbs[j][l]*Hbs[j][m]
                        elseif abs(m-l) == 1
                            Hsc[j,k] += Λ(1,d,C6,R)*Hbs[j][l]*Hbs[j][m]
                        elseif abs(m-l) == 2
                            Hsc[j,k] += Λ(2,d,C6,R)*Hbs[j][l]*Hbs[j][m]
                        else
                            continue
                        end
                    end
                end
            end
        end
    end
    return Hsc
end
# Out:
# Hsc (generic function with 1 method)

# %%
function Hsc_new(;Λ::Float64)
    Hsc = zeros(Float64, Lb, Lb)
    for j in 1:Lb
        for k in 1:Lb
            if j == k
                for l in 1:Ls
                    for m in 1:Ls
                        if l-m == 0
                            Hsc[j,k] += 0
                        elseif abs(m-l) == 1
                            Hsc[j,k] += Λ*Hbs[j][l]*Hbs[j][m]
                        elseif abs(m-l) == 2
                            Hsc[j,k] += Λ/2*Hbs[j][l]*Hbs[j][m]
                        else
                            continue
                        end
                    end
                end
            end
        end
    end
    return Hsc
end
# Out:
# Hsc_new (generic function with 1 method)

# %% [markdown]
# ### Construction of the full Hamiltonian

# %%
function Htot(;γ::Float64, J::Float64, g::Float64, d::Float64, C6::Float64, R::Float64)
    Htot = Htit(γ) - J*Hhop + (g/2)*Honsite + (1/2)*Hsc(d,C6,R)
    return Htot
end
# Out:
# Htot (generic function with 1 method)

# %%
function Htot_new(;γ::Float64, J::Float64, g::Float64, Λ::Float64)
    Htot = Htit(γ) - J*Hhop + (g/2)*Honsite + (1/(2*Na))*Hsc_new(Λ=Λ)
    return Htot
end
# Out:
# Htot_new (generic function with 1 method)

# %% [markdown]
# ### Fitting the edge of the distribution

# %%
# This function is for plotting the level statistics.
function get_diffs(;v::Int64, γ::Float64, J::Float64, g::Float64, Λ::Float64)
    eigs = eigvals(Htot_new(γ=γ, J=J, g=g, Λ=Λ));
    diffs = [eigs[i+1]-eigs[i] for i in 1:length(eigs)-1];
    index1 = Int((v-1)/2)
    index2 = length(diffs)-index1
    diffs_dropped = diffs[index1:index2];
    
    new_diffs = Float64[]
    for i in 1:length(diffs_dropped)
        drop_index = Int((v-1)/2)
        if i-drop_index>0 && i+drop_index<=length(diffs_dropped)
            append!(new_diffs, diffs_dropped[i]/average_spacing(diffs_dropped, i, v))
        end
    end
    return diffs_dropped, new_diffs
end
# Out:
# get_diffs (generic function with 1 method)

# %%
function get_diffs_new(;v::Int64, step::Int64, γ::Float64, J::Float64, g::Float64, Λ::Float64)
    eigs = eigvals(Htot_new(γ=γ, J=J, g=g, Λ=Λ));
    diffs = [eigs[i+1]-eigs[i] for i in 1:length(eigs)-1];
    index1 = Int((v-1)/2)
    index2 = length(diffs)-index1
    diffs_dropped = diffs[index1:index2];
    
    new_diffs = Float64[]
    for i in 1:length(diffs_dropped)
        drop_index = Int((step-1)/2)
        if i-drop_index>0 && i+drop_index<=length(diffs_dropped)
            append!(new_diffs, diffs_dropped[i]/average_spacing(diffs_dropped, i, step))
        end
    end
    return diffs_dropped, new_diffs
end
# Out:
# get_diffs_new (generic function with 1 method)

# %%
# Manually generate the historgram bins.
# This function is prepared for later fittings.
function fit_edge(;dmin::Float64, dmax::Float64, bin::Float64, diffs::Vector{Float64}, new_diffs::Vector{Float64})
    dmin = dmin;
    dmax = dmax;
    bin = bin # the width of the bin
    Nbin = Int(floor((dmax-dmin)/bin))
    Ndstep = Int(floor(length(diffs)/v));

    xbin = [bin*(i-1) for i in 1:Nbin];
    Nenergy = vec(zeros(Float64, Nbin, 1));

    for i in 1:length(new_diffs)
        for j in 1:Nbin
            if xbin[j] <= new_diffs[i] < xbin[j+1]
                Nenergy[j] += 1
            end
        end
    end

    normNenergy = Nenergy/(bin*sum(Nenergy))
    return xbin, normNenergy
end
# Out:
# fit_edge (generic function with 1 method)

# %% [markdown]
# ### Distributions of energy eigenvalues

# %%
H1 = Htot_new(γ=2.5, J=1.0, g=0.0, Λ=7.0)
eigval = eigvals(H1)
eigvec = eigvecs(H1)
state_evolution_modified(eigenvals=eigval, eigenvecs=eigvec, t=1.0, basis=Hbs, init=vec([20 20 20]))
#eigs1 = eigvals(H1)/Na;
#hist(eigs1, bins=40)
#vec = eigvecs(H1)[:,1]

# %%
# open("./new_data/DOS/lambda=7/lambda.txt", "w") do io
#     for i in eigs1
#         println(io, i)
#     end
# end

# %% [markdown]
# ### Level statistics

# %%
# In our case, we take average every 5 levels, we drop (v-1)/2 spacings at either end.
# This value should not be changed anymore!!!!!
v = 5
# This is defined for later convenience.
f(x) = exp(-x);
ff(x) = (π*x/2)*exp(-π*x^2/4);

# %%
diffs1_dropped, new_diffs1 = get_diffs(v=v, γ=2.5, J=1.0, g=0.0, Λ=0.5);
#diffs1_dropped, new_diffs1 = get_diffs_new(v=v, step=5, γ=2.5, J=1.0, g=0.0, Λ=8.0);

# %%
p2 = Figure(resolution=(900,600))
ax2 = Axis(p2[1,1], xlabel=L"$s$", ylabel=L"$P$")
xs = 0:0.2:5;
ys = f.(xs)
ys2 = ff.(xs)
hist!(ax2, new_diffs1,bins=40, normalization=:pdf)
lines!(ax2, xs, ys, linestyle=:dot, linewidth=4, color=:red)
lines!(ax2, xs, ys2, linestyle=:dot, linewidth=4, color=:black)
p2
# Out:
# Figure()

# %%
xbins, normNenergy = fit_edge(;dmin=1.0, dmax=8.0, bin=0.1, diffs=diffs1_dropped, new_diffs=new_diffs1)

hists = Tuple{Float64, Float64}[]
for i in 1:length(xbins)-1
    push!(hists, (xbins[i],normNenergy[i]))
    push!(hists, (xbins[i+1],normNenergy[i]))
end

# %%
p3 = Figure(resolution=(900,600))
ax3 = Axis(p3[1,1], xlabel=L"$s$", ylabel=L"$P$")
scatterlines!(ax3, hists, markersize=0.0)
xs = 0:0.1:8;
ys = f.(xs)
ys2 = ff.(xs)
#hist!(ax3, new_diffs1,bins=40, normalization=:pdf)
lines!(ax3, xs, ys, linestyle=:dot, linewidth=4, color=:red)
lines!(ax3, xs, ys2, linestyle=:dot, linewidth=4, color=:black)
p3
# Out:
# Figure()

# %% [markdown]
# ### Brody distribution

# %%
# This is for saving energy levels
# Fixing γ scanning through SMALL Λ

n = 1
for Λ in 0.0:0.05:2
    diffs_dropped, new_diffs = get_diffs(v=v, γ=2.5, J=1.0, g=0.0, Λ=Λ);
    open("./new_data/energy_levels/gamma=2.5/small_lambda/N=60/$n.txt", "w") do io 
        for i in new_diffs
            println(io, i)
        end
    end
    n += 1
end

# %%
# This is for saving energy levels
# Fixing γ scanning through Λ

n = 1
for Λ in 2.0:0.05:15.0
    diffs_dropped, new_diffs = get_diffs(v=v, γ=2.5, J=1.0, g=0.0, Λ=Λ);
    open("./new_data/energy_levels/gamma=2.5/N=120/$n.txt", "w") do io 
        for i in new_diffs
            println(io, i)
        end
    end
    n += 1
end

# %%
# This is for saving energy levels
# Fixing Λ scanning through γ
n = 1
for γ in 0.0:0.05:7.0
    diffs_dropped, new_diffs = get_diffs(v=v, γ=γ, J=1.0, g=0.0, Λ=7.0);
    open("./new_data/energy_levels/lambda=7/N=120/$n.txt", "w") do io
        for i in new_diffs
            println(io, i)
        end
    end
    n += 1
end

# %%
# Due to the fact that there is no stable package of nonlinear fitting in Julia,
# I can only save the data to python to find the chaos indicator.

# Case 1: Fixing γ at 2.5. Scanning through Λ
for Λ in 2.0:0.05:15.0
    diffs_dropped, new_diffs = get_diffs(v=v, γ=2.5, J=1.0, g=0.0, Λ=Λ);
    xbin, normNenergy = fit_edge(dmin=1.0, dmax=8.0, bin=0.1, diffs=diffs_dropped, new_diffs=new_diffs)
    open("./new_data/gamma=2.5/N=60/Lambda=$Λ.txt", "w") do io 
        for i in normNenergy
            println(io, i)
        end
    end
end

# %%
# Case 2: Fixing Λ. Scanning through γ.
for γ in 0.0:0.05:7.0
    diffs_dropped, new_diffs = get_diffs_new(v=v, step=5, γ=γ, J=1.0, g=0.0, Λ=8.0)
    xbin, normNenergy = fit_edge(dmin=0.0, dmax=8.0, bin=0.1, diffs=diffs_dropped, new_diffs=new_diffs)
    open("./new_data/Lambda=8.0/N=60/gamma=$γ.txt", "w") do io
        for i in normNenergy
            println(io, i)
        end
    end
end

# %% [markdown]
# ### Plots

# %%
J = 1.0;
g = 0.0;
γs = 0.0:0.1:5.0;
Λs = -1.0:0.01:1.0
Λs_new = 0.0:0.1:15.0
# Out:
# 0.0:0.1:15.0

# %%
for Λ in Λs_new
    diffs_dropped, new_diffs = get_diffs(v=v, γ=0.5, J=1.0, g=0.0, Λ=Λ);
    p = Figure(resolution=(900,600))
    ax = Axis(p[1,1], xlabel=L"$s$", ylabel=L"$P$")
    ax.title = "Λ=$Λ"
    xs = 0:0.2:8;
    ys = f.(xs)
    ys2 = ff.(xs)
    hist!(ax, new_diffs,bins=40, normalization=:pdf)
    lines!(ax, xs, ys, linestyle=:dot, linewidth=4, color=:red)
    lines!(ax, xs, ys2, linestyle=:dot, linewidth=4, color=:black)
    save("./juliapics/levelstat/N=60/gamma=0.5/Λ=$Λ.png", p)
end

# %%
for Λ in Λs_new
    diffs_dropped, new_diffs = get_diffs(v=v, γ=2.5, J=1.0, g=0.0, Λ=Λ);
    p = Figure(resolution=(900,600))
    ax = Axis(p[1,1], xlabel=L"$s$", ylabel=L"$P$")
    ax.title = "Λ=$Λ"
    xs = 0:0.2:8;
    ys = f.(xs)
    ys2 = ff.(xs)
    hist!(ax, new_diffs,bins=40, normalization=:pdf)
    lines!(ax, xs, ys, linestyle=:dot, linewidth=4, color=:red)
    lines!(ax, xs, ys2, linestyle=:dot, linewidth=4, color=:black)
    save("./juliapics/levelstat/N=60/gamma=2.5/Λ=$Λ.png", p)
end

# %% [markdown]
# ### Energy levels

# %%
Λs_new = 0.0:0.1:15.0
# Out:
# 0.0:0.1:15.0

# %%
# Here we consider the case of N = 12
eig_mat = zeros(Float64, Lb, length(Λs_new))
i = 1
for Λ in Λs_new
    H = Htot_new(γ=0.0, J=1.0, g=0.0, Λ=Λ)
    eigs = eigvals(H)
    eig_mat[:,i] = eigs/Na
    i += 1
end

# %%
# df = DataFrame(eig_mat,:auto)
# CSV.write("./new_data/energy_levels/N=12/gamma=0/gamma=0.csv", df)
# Out:
# "./new_data/energy_levels/N=12/gamma=0/gamma=0.csv"

# %%
p4 = Figure(resolution=(900,600))
ax4 = Axis(p4[1,1], xlabel=L"$U/J$", ylabel=L"$E/J$")
for i in 1:Lb
    lines!(ax4, Λs_new, eig_mat[i,:])
end

# %%
p4
# Out:
# Figure()

# %% [markdown]
# ### Plot respect to $\gamma$

# %%
γs = 2.0:0.01:3.0
# Out:
# 2.0:0.01:3.0

# %%
eig_mat2 = zeros(Float64, Lb, length(γs))
i = 1
for γ in γs
    H = Htot_new(γ=γ, J=1.0, g=0.0, Λ=7.0)
    eigs = eigvals(H)
    eig_mat2[:,i] = eigs/Na
    i += 1
end

# %%
df2 = DataFrame(eig_mat2,:auto);
CSV.write("./new_data/energy_levels/N=12/lambda=7/gamma2to3.csv",df2)
# Out:
# "./new_data/energy_levels/N=12/lambda=7/gamma2to3.csv"

# %%
p5 = Figure(resolution=(900,600))
ax5 = Axis(p5[1,1], xlabel=L"$γ/J$", ylabel=L"$E/J$")
for i in 48:60
    lines!(ax5, γs, eig_mat2[i,:],color=:blue)
end
p5
# Out:
# Figure()

# %%
# Dict1 = Dict{Float64, Vector{Vector{Float64}}}(i=>[] for i in Λs);

# %%
# for Λ in Λs
#     for γ in γs
#         H = Htot_new(γ=γ, J=1.0, g=g, Λ=Λ)
#         eigs = eigvals(H)
#         push!(Dict1[Λ], eigs)
#     end
# end

# %%
# # Plot the diagrams w.r.t γ
# fontsize_theme = Theme(fontsize = 45)
# set_theme!(fontsize_theme)

# for Λ in Λs
#     eigs = Dict1[Λ];
#     eigs_mat = zeros(Float64, length(γs), Lb);
#     for i in 1:length(γs)
#         eigs_mat[i,:] = eigs[i]
#     end
    
#     f = Figure(resolution=(1000,1000))
#     ax = Axis(f[1,1], xlabel=L"\gamma", ylabel=L"\epsilon")
#     ax.title = "Λ=$Λ"
#     for i in 1:Lb
#         lines!(ax, γs, eigs_mat[:,i])
#     end
#     save("/Users/tianyiyan/Desktop/Chaos/juliapics/spectrum_less/lambda=$Λ.png",f)
# end

# %% [markdown]
# ### Entanglement entropy

# %%
# I now only makes this function works given the initial state with equal
# number of atoms in each site. But I potentially can extend it to arbitrary initial state.
function evolEE(;H::Matrix{Float64},t::Float64,basis::Vector{Vector{Int64}},init::Vector{Int})
    
    if t == 0.0
        EE = 0.0
    else
        vec = state_evolution(H=H,t=t,basis=basis,init=init)
        rdmat = reduced_density_matrix(state=vec, Na=Na, Ls=Ls, Rd=1)
        vals = svd(rdmat).S
        # display(vals)
        EE = -transpose(vals)*log.(vals)
    end
    
    return EE
end


function evolEE_modified(;eigenvals::Vector{Float64},eigenvecs::Matrix{Float64},t::Float64,basis::Vector{Vector{Int64}},init::Vector{Int})
    if t == 0.0
        EE = 0.0
    else
        vec = state_evolution_modified(eigenvals=eigenvals,eigenvecs=eigenvecs,t=t,basis=basis,init=init)
        rdmat = reduced_density_matrix_modified(Na=Na, state=vec, Hbs=Hbs)
        vals = svd(rdmat).S
        # display(vals)
        EE = -transpose(vals)*log.(vals)
    end
    
    return EE
end
# Out:
# evolEE_modified (generic function with 1 method)

# %%
# Evolve w.r.t Λ

Λs = 0.0:0.5:15.0
ts = 0.0:0.1:5.0
aveEEs = zeros(Float64, 1, length(Λs))
std_ee = zeros(Float64, 1, length(Λs))
@time for i in 1:length(Λs)
    lambda = Λs[i]
    H = Htot_new(γ=2.5, J=1.0, g=0.0, Λ=lambda)
    evolEEs = [evolEE(H=H,t=t,basis=Hbs,init=vec([20 20 20])) for t in ts]
    len = length(evolEEs)
    drop_rate = 0.2 # we drop the first 20% of data
    left_num = Int(floor(drop_rate*len))
    aveEEs[i] = mean(evolEEs[left_num:len])
    std_ee[i] = std(evolEEs[left_num:len])
    display(aveEEs)
end

# %%
# Evolve w.r.t γ

γs = 0.0:0.5:7.0
ts = 0.0:0.1:5.0
aveEEs_new = zeros(Float64, 1, length(γs))
std_ee_new = zeros(Float64, 1, length(γs))
@time for i in 1:length(γs)
    γ = γs[i]
    H = Htot_new(γ=γ, J=1.0, g=0.0, Λ=0.5)
    eigenvals = eigvals(H)
    eigenvecs = eigvecs(H)
    evolEEs = [evolEE_modified(eigenvals=eigenvals,eigenvecs=eigenvecs,t=t,basis=Hbs,init=vec([20 20 20])) for t in ts]
    len = length(evolEEs)
    drop_rate = 0.2 # we drop the first 20% of data
    left_num = Int(floor(drop_rate*len))
    aveEEs_new[i] = mean(evolEEs[left_num:len])
    std_ee_new[i] = std(evolEEs[left_num:len])
    display(aveEEs_new)
end
# Out:
# InterruptException:
#
# Stacktrace:
#   [1] _unsafe_copyto!(dest::Matrix{ComplexF64}, doffs::Int64, src::Matrix{Complex}, soffs::Int64, n::Int64)
#     @ Base ./array.jl:253
#   [2] unsafe_copyto!
#     @ ./array.jl:307 [inlined]
#   [3] _copyto_impl!
#     @ ./array.jl:331 [inlined]
#   [4] copyto!
#     @ ./array.jl:317 [inlined]
#   [5] copyto!
#     @ ./array.jl:343 [inlined]
#   [6] copyto_axcheck!(dest::Matrix{ComplexF64}, src::Matrix{Complex})
#     @ Base ./abstractarray.jl:1104
#   [7] AbstractArray
#     @ ./array.jl:564 [inlined]
#   [8] convert
#     @ ./abstractarray.jl:18 [inlined]
#   [9] copy_oftype
#     @ /Applications/Julia-1.7.app/Contents/Resources/julia/share/julia/stdlib/v1.7/LinearAlgebra/src/LinearAlgebra.jl:359 [inlined]
#  [10] #svd#101
#     @ /Applications/Julia-1.7.app/Contents/Resources/julia/share/julia/stdlib/v1.7/LinearAlgebra/src/svd.jl:176 [inlined]
#  [11] svd
#     @ /Applications/Julia-1.7.app/Contents/Resources/julia/share/julia/stdlib/v1.7/LinearAlgebra/src/svd.jl:176 [inlined]
#  [12] evolEE_modified(; eigenvals::Vector{Float64}, eigenvecs::Matrix{Float64}, t::Float64, basis::Vector{Vector{Int64}}, init::Vector{Int64})
#     @ Main ./In[21]:25
#  [13] (::var"#19#20"{Matrix{Float64}, Vector{Float64}})(t::Float64)
#     @ Main ./none:0
#  [14] iterate
#     @ ./generator.jl:47 [inlined]
#  [15] collect_to!
#     @ ./array.jl:782 [inlined]
#  [16] collect_to_with_first!
#     @ ./array.jl:760 [inlined]
#  [17] collect(itr::Base.Generator{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, var"#19#20"{Matrix{Float64}, Vector{Float64}}})
#     @ Base ./array.jl:734
#  [18] eval
#     @ ./boot.jl:373 [inlined]
#  [19] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196

# %%
H1 = Htot_new(γ=2.5, J=1.0, g=0.0, Λ=7.0)
eigval = eigvals(H1)
eigvec = eigvecs(H1);

# %%
@time Vec = state_evolution_modified(eigenvals=eigval, eigenvecs=eigvec, t=1.0, basis=Hbs, init=vec([20 20 20]));
# Out:
#   0.045078 seconds (9.47 k allocations: 136.962 MiB, 47.81% gc time)

# %%
@time rdmat = reduced_density_matrix_modified(Na=Na, state=Vec, Hbs=Hbs);
# Out:
#   0.037838 seconds (78.85 k allocations: 86.251 MiB, 48.59% gc time)

# %%
@time s = svd(rdmat, alg=LinearAlgebra.DivideAndConquer()).S
# Out:
#   6.147487 seconds (3.58 M allocations: 356.792 MiB, 0.24% gc time)
# 1891-element Vector{Float64}:
#  0.03393229513401002
#  0.03093134164135716
#  0.030842590537320597
#  0.029602950279408163
#  0.029118563317513696
#  0.028894297091489596
#  0.0281916693958782
#  0.026503383555431335
#  0.025536792969092937
#  0.02549504805150144
#  0.024703453961192414
#  0.024383572343769058
#  0.02392489444254975
#  ⋮
#  1.2629027435459695e-19
#  1.004590312995857e-19
#  1.0027014270036631e-19
#  8.959258588734337e-20
#  6.466572338020934e-20
#  3.611411260866662e-20
#  4.584911658966653e-21
#  2.0182973094916692e-21
#  1.8275748960961596e-22
#  9.101966650597375e-23
#  2.6123638286204084e-23
#  7.557658588202246e-24

# %%
@time evolEE_modified(eigenvals=eigval,eigenvecs=eigvec,t=1.0,basis=Hbs,init=vec([20 20 20]))
# Out:
#   6.376057 seconds (3.66 M allocations: 580.035 MiB, 0.31% gc time)
# 3.3194020847099455

# %%
lines(γs, vec(aveEEs_new))
# Out:
# FigureAxisPlot()
